# %%
from pstats import Stats
import matplotlib.pyplot as plt
from typing import Any

# %%
problems = [
    "translated_imo_2000_p1",
    "translated_imo_2000_p6",
    "translated_imo_2002_p2a",
    "translated_imo_2002_p2b",
    "translated_imo_2003_p4",
    "translated_imo_2004_p1",
    "translated_imo_2004_p5",
    "translated_imo_2005_p5",
    "translated_imo_2007_p4",
    "translated_imo_2008_p1a",
    "translated_imo_2008_p1b",
    # "translated_imo_2008_p6",
    "translated_imo_2009_p2",
    "translated_imo_2010_p2",
    "translated_imo_2010_p4",
    "translated_imo_2011_p6",
    "translated_imo_2012_p1",
    "translated_imo_2012_p5",
    "translated_imo_2013_p4",
    "translated_imo_2014_p4",
    "translated_imo_2015_p3",
    "translated_imo_2015_p4",
    "translated_imo_2016_p1",
    "translated_imo_2017_p4",
    "translated_imo_2018_p1",
    "translated_imo_2019_p2",
    "translated_imo_2019_p6",
    "translated_imo_2020_p1",
    "translated_imo_2021_p3",
    "translated_imo_2022_p4",
]

# %%
for problem in problems:
    with open(f"C:/Users/vwx1257668/Desktop/Projects/AlphaGeo/newclid/profiling_exp/{problem}/run_infos.txt", "r", encoding='utf-8') as f:
        # print("original rule set", problem, eval(f.read())['success'], eval(f.read())['runtime'])
        print("original rule set", problem, eval(f.read())['runtime'])
# Out:
# original rule set translated_imo_2000_p1 811.9390771389008
# original rule set translated_imo_2000_p6 8371.561145067215
# original rule set translated_imo_2002_p2a 112.85705971717834
# original rule set translated_imo_2002_p2b 112.40153908729553
# original rule set translated_imo_2003_p4 798.7773571014404
# original rule set translated_imo_2004_p1 439.6988196372986
# original rule set translated_imo_2004_p5 18.873297929763794
# original rule set translated_imo_2005_p5 1377.0051019191742
# original rule set translated_imo_2007_p4 813.5918779373169
# original rule set translated_imo_2008_p1a 2288.5287363529205
# original rule set translated_imo_2008_p1b 2286.6677918434143
# original rule set translated_imo_2009_p2 445.6793541908264
# original rule set translated_imo_2010_p2 441.84201526641846
# original rule set translated_imo_2010_p4 231.29077816009521
# original rule set translated_imo_2011_p6 12190.260713338852
# original rule set translated_imo_2012_p1 825.8394205570221
# original rule set translated_imo_2012_p5 111.31814694404602
# original rule set translated_imo_2013_p4 819.9302780628204
# original rule set translated_imo_2014_p4 242.31109261512756
# original rule set translated_imo_2015_p3 831.7562727928162
# original rule set translated_imo_2015_p4 2458.9415707588196
# original rule set translated_imo_2016_p1 465.2691488265991
# original rule set translated_imo_2017_p4 245.26467776298523
# original rule set translated_imo_2018_p1 123.19664859771729
# original rule set translated_imo_2019_p2 250.4311399459839
# original rule set translated_imo_2019_p6 2425.484671831131
# original rule set translated_imo_2020_p1 1448.6337213516235
# original rule set translated_imo_2021_p3 486.43813467025757
# original rule set translated_imo_2022_p4 448.01445627212524

# %%
for problem in problems:
    with open(f"../profiling_opt/{problem}/run_infos.txt", "r", encoding='utf-8') as f:
        print("optimized rule set", problem, eval(f.read())['runtime'])
# Out:
# optimized rule set translated_imo_2000_p1 687.7260217666626
# optimized rule set translated_imo_2000_p6 7311.118611812592
# optimized rule set translated_imo_2002_p2a 96.37491965293884
# optimized rule set translated_imo_2002_p2b 96.20866560935974
# optimized rule set translated_imo_2003_p4 695.0639133453369
# optimized rule set translated_imo_2004_p1 376.76526975631714
# optimized rule set translated_imo_2004_p5 15.513340711593628
# optimized rule set translated_imo_2005_p5 1183.8947706222534
# optimized rule set translated_imo_2007_p4 654.4989140033722
# optimized rule set translated_imo_2008_p1a 1914.4817657470703
# optimized rule set translated_imo_2008_p1b 1910.0397844314575
# optimized rule set translated_imo_2009_p2 373.13578724861145
# optimized rule set translated_imo_2010_p2 378.61624002456665
# optimized rule set translated_imo_2010_p4 194.68379473686218
# optimized rule set translated_imo_2011_p6 10905.937153577805
# optimized rule set translated_imo_2012_p1 704.0762956142426
# optimized rule set translated_imo_2012_p5 91.67831301689148
# optimized rule set translated_imo_2013_p4 729.9004371166229
# optimized rule set translated_imo_2014_p4 193.24606919288635
# optimized rule set translated_imo_2015_p3 701.2251396179199
# optimized rule set translated_imo_2015_p4 2032.5777659416199
# optimized rule set translated_imo_2016_p1 398.3407874107361
# optimized rule set translated_imo_2017_p4 233.74405241012573
# optimized rule set translated_imo_2018_p1 101.49884843826294
# optimized rule set translated_imo_2019_p2 207.81413960456848
# optimized rule set translated_imo_2019_p6 2131.3946661949158
# optimized rule set translated_imo_2020_p1 1336.2656869888306
# optimized rule set translated_imo_2021_p3 412.44153451919556
# optimized rule set translated_imo_2022_p4 374.3206889629364

# %%
from sklearn.linear_model import LinearRegression, HuberRegressor
import numpy as np
x: list[float] = []
y: list[float] = []
for problem in problems:
    with open(f"../profiling_exp/{problem}/run_infos.txt", "r", encoding='utf-8') as f:
        x.append(eval(f.read())['runtime'])
for problem in problems:
    with open(f"../profiling_opt/{problem}/run_infos.txt", "r", encoding='utf-8') as f:
        y.append(eval(f.read())['runtime'])
data_x = np.array(x).reshape(-1, 1)
data_y = np.array(y)
plt.figure(figsize=(20, 20))
plt.axline((0, 0), (1, 1))
plt.scatter(x, y, s=10)
# for i in range(len(problems)):
#     plt.annotate(f"{y[i]/x[i]:.2f}", (x[i], y[i]))
mse = LinearRegression()
mae = HuberRegressor()
mse.fit(data_x, data_y)
mae.fit(data_x, data_y)
plt.axline((0, mse.intercept_), slope=mse.coef_[0], color='green', label="MSE")
plt.axline((0, mae.intercept_), slope=mae.coef_[0], color='black', label="MAE")
plt.axline((0,0), slope=sum(y[i]/x[i] for i in range(len(problems)))/len(problems), color='grey', label="Mean opt")
plt.axhline(0, color='grey')
plt.axvline(0, color='grey')
# plt.xscale('log')
# plt.yscale('log')
plt.xlim(-200, 4000)
plt.ylim(-200, 4000)
plt.legend()
print(mse.coef_, mse.intercept_)
print(mae.coef_, mae.intercept_)
# Out:
# [0.88766435] -26.609754522343792
# [0.87594637] -11.743861146718517

# %%
stats = Stats(f'../profiling_exp/translated_imo_2000_p1/profile.prof')
stats.print_callees()
# Out:
#    Random listing order was used
#
# Function                                                                                                                        called...
#                                                                                                                                     ncalls  tottime  cumtime
# /usr/local/lib/python3.11/encodings/__init__.py:43(normalize_encoding)                                                          ->       1    0.000    0.000  {built-in method builtins.isinstance}
#                                                                                                                                         14    0.000    0.000  {method 'append' of 'list' objects}
#                                                                                                                                         14    0.000    0.000  {method 'isalnum' of 'str' objects}
#                                                                                                                                         13    0.000    0.000  {method 'isascii' of 'str' objects}
#                                                                                                                                          1    0.000    0.000  {method 'join' of 'str' objects}
# /usr/local/lib/python3.11/contextlib.py:558(__exit__)                                                                           ->       3    0.000    0.000  /usr/local/lib/python3.11/contextlib.py:141(__exit__)
#                                                                                                                                          8    0.000    0.000  {built-in method sys.exc_info}
#                                                                                                                                          3    0.000    0.000  {method 'pop' of 'collections.deque' objects}
# /usr/local/lib/python3.11/encodings/__init__.py:71(search_function)                                                             ->       1    0.000    0.000  /usr/local/lib/python3.11/encodings/__init__.py:43(normalize_encoding)
#                                                                                                                                          1    0.000    0.000  /usr/local/lib/python3.11/encodings/unicode_escape.py:37(getregentry)
#                                                                                                                                          1    0.000    0.001  {built-in method builtins.__import__}
#                                                                                                                                          1    0.000    0.000  {built-in method builtins.isinstance}
#                                                                                                                                          3    0.000    0.000  {method 'get' of 'dict' objects}
#                                                                                                                                          1    0.000    0.000  {method 'replace' of 'str' objects}
# /usr/local/lib/python3.11/tempfile.py:682(SpooledTemporaryFile)                                                                 ->
# /venv/lib/python3.11/site-packages/packaging/version.py:188(__init__)                                                           ->      41    0.000    0.000  /venv/lib/python3.11/site-packages/packaging/version.py:207(<genexpr>)
#                                                                                                                                         33    0.000    0.000  /venv/lib/python3.11/site-packages/packaging/version.py:454(_parse_letter_version)
#                                                                                                                                         11    0.000    0.000  /venv/lib/python3.11/site-packages/packaging/version.py:492(_parse_local_version)
#                                                                                                                                         11    0.000    0.000  /venv/lib/python3.11/site-packages/packaging/version.py:504(_cmpkey)
#                                                                                                                                        110    0.000    0.000  {method 'group' of 're.Match' objects}
#                                                                                                                                         11    0.000    0.000  {method 'search' of 're.Pattern' objects}
#                                                                                                                                         11    0.000    0.000  {method 'split' of 'str' objects}
# /venv/lib/python3.11/site-packages/matplotlib/cbook.py:259(disconnect)                                                          ->       3    0.000    0.000  /venv/lib/python3.11/site-packages/matplotlib/cbook.py:106(__hash__)
#                                                                                                                                          3    0.000    0.000  {built-in method builtins.len}
#                                                                                                                                          3    0.000    0.000  {method 'discard' of 'set' objects}
#                                                                                                                                          6    0.000    0.000  {method 'items' of 'dict' objects}
#                                                                                                                                          9    0.000    0.000  {method 'pop' of 'dict' objects}
# /usr/local/lib/python3.11/random.py:128(seed)                                                                                   ->       2    0.000    0.000  {built-in method builtins.isinstance}
#                                                                                                                                          1    0.000    0.000  {function Random.seed at 0x7fde656dbce0}
# /venv/lib/python3.11/site-packages/packaging/version.py:1(<module>)                                                             ->       1    0.000    0.000  /usr/local/lib/python3.11/re/__init__.py:225(compile)
#                                                                                                                                         12    0.000    0.000  /usr/local/lib/python3.11/typing.py:373(inner)
#                                                                                                                                          1    0.000    0.000  /usr/local/lib/python3.11/typing.py:1641(__getitem__)
#                                                                                                                                          1    0.000    0.000  <frozen importlib._bootstrap>:405(parent)
#                                                                                                                                          1    0.000    0.000  <frozen importlib._bootstrap>:1165(_find_and_load)
#                                                                                                                                          4    0.000    0.003  {built-in method builtins.__build_class__}
# /venv/lib/python3.11/site-packages/matplotlib/cbook.py:203(__setstate__)                                                        ->     174    0.000    0.000  /venv/lib/python3.11/site-packages/matplotlib/cbook.py:206(<dictcomp>)
#                                                                                                                                        174    0.000    0.000  /venv/lib/python3.11/site-packages/matplotlib/cbook.py:210(<dictcomp>)
#                                                                                                                                        174    0.000    0.000  {built-in method builtins.vars}
#                                                                                                                                        348    0.000    0.000  {method 'items' of 'dict' objects}
#                                                                                                                                        174    0.000    0.000  {method 'pop' of 'dict' objects}
#                                                                                                                                        174    0.000    0.000  {method 'update' of 'dict' objects}
# /usr/local/lib/python3.11/tempfile.py:1(<module>)                                                                               ->       1    0.000    0.003  <frozen importlib._bootstrap>:1165(_find_and_load)
#                                                                                                                                          1    0.000    0.000  {built-in method _thread.allocate_lock}
#                                                                                                                                          5    0.000    0.000  {built-in method builtins.__build_class__}
#                                                                                                                                          4    0.000    0.000  {built-in method builtins.hasattr}
# /usr/local/lib/python3.11/ipaddress.py:1282(__init__)                                                                           ->      10    0.000    0.000  /usr/local/lib/python3.11/ipaddress.py:415(_check_int_address)
#                                                                                                                                         20    0.000    0.000  /usr/local/lib/python3.11/ipaddress.py:1183(_ip_int_from_string)
#                                                                                                                                         50    0.000    0.000  {built-in method builtins.isinstance}
# /usr/local/lib/python3.11/ipaddress.py:671(_BaseNetwork)                                                                        ->       2    0.000    0.000  /usr/local/lib/python3.11/functools.py:966(__init__)
# /usr/local/lib/python3.11/types.py:77(resolve_bases)                                                                            ->       1    0.000    0.000  {built-in method builtins.isinstance}
# /venv/lib/python3.11/site-packages/matplotlib/transforms.py:211(BboxBase)                                                       ->       1    0.000    0.000  /venv/lib/python3.11/site-packages/matplotlib/_api/__init__.py:44(__init__)
#                                                                                                                                          1    0.000    0.000  /venv/lib/python3.11/site-packages/matplotlib/_api/deprecation.py:102(deprecated)
#                                                                                                                                          1    0.000    0.000  /venv/lib/python3.11/site-packages/matplotlib/_api/deprecation.py:131(deprecate)
#                                                                                                                                          2    0.000    0.000  /venv/lib/python3.11/site-packages/matplotlib/_api/deprecation.py:260(rename_parameter)
# /usr/local/lib/python3.11/re/_parser.py:456(_parse_sub)                                                                         ->     105    0.000    0.000  /usr/local/lib/python3.11/re/_parser.py:113(__init__)
#                                                                                                                                        234    0.000    0.000  /usr/local/lib/python3.11/re/_parser.py:164(__len__)
#                                                                                                                                         15    0.000    0.000  /usr/local/lib/python3.11/re/_parser.py:166(__delitem__)
#                                                                                                                                        310    0.000    0.000  /usr/local/lib/python3.11/re/_parser.py:168(__getitem__)
#                                                                                                                                        110    0.000    0.000  /usr/local/lib/python3.11/re/_parser.py:176(append)
#                                                                                                                                       1123    0.000    0.000  /usr/local/lib/python3.11/re/_parser.py:256(match)
#                                                                                                                                        893    0.000    0.000  /usr/local/lib/python3.11/re/_parser.py:293(tell)
#                                                                                                                                          4    0.000    0.000  /usr/local/lib/python3.11/re/_parser.py:453(_uniq)
#                                                                                                                                   1123/408    0.022    0.054  /usr/local/lib/python3.11/re/_parser.py:516(_parse)
#                                                                                                                                       1034    0.000    0.000  {built-in method builtins.len}
#                                                                                                                                       1153    0.000    0.000  {method 'append' of 'list' objects}
#                                                                                                                                         10    0.000    0.000  {method 'extend' of 'list' objects}
# /usr/local/lib/python3.11/re/_compiler.py:740(compile)                                                                          ->     367    0.000    0.000  /usr/local/lib/python3.11/re/_compiler.py:570(isstring)
#                                                                                                                                        367    0.001    0.031  /usr/local/lib/python3.11/re/_compiler.py:573(_code)
#                                                                                                                                        734    0.000    0.000  /usr/local/lib/python3.11/re/_parser.py:83(groups)
#                                                                                                                                        367    0.002    0.059  /usr/local/lib/python3.11/re/_parser.py:979(parse)
#                                                                                                                                        367    0.000    0.000  {built-in method _sre.compile}
#                                                                                                                                        367    0.000    0.000  {method 'items' of 'dict' objects}
# /usr/local/lib/python3.11/types.py:247(coroutine)                                                                               ->       2    0.000    0.000  {built-in method builtins.callable}
#                                                                                                                                          2    0.000    0.000  {built-in method builtins.getattr}
#                                                                                                                                          2    0.000    0.000  {method 'replace' of 'code' objects}
# /usr/local/lib/python3.11/warnings.py:131(filterwarnings)                                                                       ->       4    0.000    0.001  /usr/local/lib/python3.11/re/__init__.py:225(compile)
#                                                                                                                                          5    0.000    0.000  /usr/local/lib/python3.11/warnings.py:182(_add_filter)
#                                                                                                                                         20    0.000    0.000  {built-in method builtins.isinstance}
#                                                                                                                                          5    0.000    0.000  {built-in method builtins.issubclass}
# /usr/local/lib/python3.11/contextlib.py:141(__exit__)                                                                           -> 2845/2772    0.001    0.012  {built-in method builtins.next}
# /usr/local/lib/python3.11/collections/__init__.py:350(namedtuple)                                                               ->      92    0.005    0.005  {built-in method builtins.eval}
#                                                                                                                                         92    0.000    0.000  {built-in method builtins.isinstance}
#                                                                                                                                        190    0.000    0.000  {built-in method builtins.len}
#                                                                                                                                         44    0.000    0.000  {built-in method sys._getframe}
#                                                                                                                                        456    0.000    0.000  {built-in method sys.intern}
#                                                                                                                                        456    0.000    0.000  {method '__contains__' of 'frozenset' objects}
#                                                                                                                                        364    0.000    0.000  {method 'add' of 'set' objects}
#                                                                                                                                         44    0.000    0.000  {method 'get' of 'dict' objects}
#                                                                                                                                        456    0.000    0.000  {method 'isidentifier' of 'str' objects}
#                                                                                                                                        184    0.000    0.000  {method 'join' of 'str' objects}
#                                                                                                                                         31    0.000    0.000  {method 'replace' of 'str' objects}
#                                                                                                                                         31    0.000    0.000  {method 'split' of 'str' objects}
#                                                                                                                                        364    0.000    0.000  {method 'startswith' of 'str' objects}
# /usr/local/lib/python3.11/warnings.py:467(__enter__)                                                                            ->      31    0.000    0.000  {built-in method _warnings._filters_mutated}
# /usr/local/lib/python3.11/functools.py:800(singledispatch)                                                                      ->       4    0.000    0.000  /usr/local/lib/python3.11/functools.py:35(update_wrapper)
#                                                                                                                                          4    0.000    0.000  /usr/local/lib/python3.11/weakref.py:367(__init__)
#                                                                                                                                          4    0.000    0.000  {built-in method builtins.getattr}
# /usr/local/lib/python3.11/functools.py:852(register)                                                                            ->       3    0.000    0.000  /usr/local/lib/python3.11/functools.py:841(_is_union_type)
#                                                                                                                                          4    0.000    0.000  /usr/local/lib/python3.11/functools.py:845(_is_valid_dispatch_type)
#                                                                                                                                          3    0.000    0.000  <frozen _collections_abc>:933(clear)
#                                                                                                                                          3    0.000    0.000  {built-in method builtins.hasattr}
# /usr/local/lib/python3.11/functools.py:981(__get__)                                                                             ->       6    0.000    0.002  /venv/lib/python3.11/site-packages/pyparsing/core.py:3045(re)
#                                                                                                                                          6    0.000    0.002  /venv/lib/python3.11/site-packages/pyparsing/core.py:3055(re_match)
#                                                                                                                                         12    0.000    0.000  {method '__exit__' of '_thread.RLock' objects}
#                                                                                                                                         24    0.000    0.000  {method 'get' of 'dict' objects}
# /usr/local/lib/python3.11/enum.py:1095(__new__)                                                                                 ->       6    0.000    0.000  /usr/local/lib/python3.11/enum.py:1377(_missing_)
#                                                                                                                                          6    0.000    0.000  {built-in method builtins.isinstance}
# /usr/local/lib/python3.11/enum.py:1377(_missing_)                                                                               ->      20    0.000    0.000  /usr/local/lib/python3.11/enum.py:1367(_iter_member_by_def_)
#                                                                                                                                          6    0.000    0.000  /usr/local/lib/python3.11/enum.py:1453(<listcomp>)
#                                                                                                                                          6    0.000    0.000  {built-in method __new__ of type object at 0x7fde6656be80}
#                                                                                                                                          6    0.000    0.000  {built-in method builtins.hasattr}
#                                                                                                                                          6    0.000    0.000  {built-in method builtins.isinstance}
#                                                                                                                                         14    0.000    0.000  {method 'append' of 'list' objects}
#                                                                                                                                          6    0.000    0.000  {method 'join' of 'str' objects}
#                                                                                                                                          6    0.000    0.000  {method 'setdefault' of 'dict' objects}
# /usr/local/lib/python3.11/enum.py:242(__set_name__)                                                                             ->       8    0.000    0.000  /usr/local/lib/python3.11/enum.py:93(_is_single_bit)
#                                                                                                                                         11    0.000    0.000  /usr/local/lib/python3.11/enum.py:828(__setattr__)
#                                                                                                                                        707    0.000    0.000  /usr/local/lib/python3.11/enum.py:1151(__init__)
#                                                                                                                                          4    0.000    0.000  /usr/local/lib/python3.11/ssl.py:461(__new__)
#                                                                                                                                        705    0.000    0.000  {built-in method __new__ of type object at 0x7fde6656be80}
#                                                                                                                                        707    0.000    0.001  {built-in method builtins.delattr}
#                                                                                                                                        707    0.000    0.000  {built-in method builtins.hasattr}
#                                                                                                                                        715    0.000    0.000  {built-in method builtins.isinstance}
#                                                                                                                                       1406    0.000    0.000  {built-in method builtins.issubclass}
#                                                                                                                                        707    0.000    0.000  {built-in method builtins.len}
#                                                                                                                                        707    0.000    0.001  {built-in method builtins.setattr}
#                                                                                                                                        694    0.000    0.000  {method 'append' of 'list' objects}
#                                                                                                                                          4    0.000    0.000  {method 'bit_length' of 'int' objects}
#                                                                                                                                       2742    0.000    0.000  {method 'get' of 'mappingproxy' objects}
#                                                                                                                                        707    0.000    0.000  {method 'setdefault' of 'dict' objects}
# /usr/local/lib/python3.11/enum.py:841(_create_)                                                                                 ->      13    0.000    0.000  /usr/local/lib/python3.11/enum.py:367(__setitem__)
#                                                                                                                                          3    0.000    0.000  /usr/local/lib/python3.11/enum.py:484(__prepare__)
#                                                                                                                                          3    0.000    0.000  /usr/local/lib/python3.11/enum.py:499(__new__)
#                                                                                                                                          3    0.000    0.000  /usr/local/lib/python3.11/enum.py:943(_get_mixins_)
#                                                                                                                                         10    0.000    0.000  /usr/local/lib/python3.11/enum.py:1154(_generate_next_value_)
#                                                                                                                                         19    0.000    0.000  {built-in method builtins.isinstance}
#                                                                                                                                          2    0.000    0.000  {built-in method sys._getframe}
#                                                                                                                                         20    0.000    0.000  {method 'append' of 'list' objects}
#                                                                                                                                          2    0.000    0.000  {method 'replace' of 'str' objects}
#                                                                                                                                          2    0.000    0.000  {method 'split' of 'str' objects}
# /usr/local/lib/python3.11/re/_parser.py:304(checkgroupname)                                                                     ->      78    0.000    0.000  {method 'isidentifier' of 'str' objects}
# /usr/local/lib/python3.11/enum.py:1668(convert_class)                                                                           ->     312    0.000    0.000  /usr/local/lib/python3.11/enum.py:38(_is_descriptor)
#                                                                                                                                        355    0.000    0.000  /usr/local/lib/python3.11/enum.py:48(_is_dunder)
#                                                                                                                                        312    0.000    0.000  /usr/local/lib/python3.11/enum.py:59(_is_sunder)
#                                                                                                                                        312    0.000    0.000  /usr/local/lib/python3.11/enum.py:79(_is_private)
#                                                                                                                                         41    0.000    0.000  /usr/local/lib/python3.11/enum.py:93(_is_single_bit)
#                                                                                                                                        312    0.000    0.000  /usr/local/lib/python3.11/enum.py:229(__set_name__)
#                                                                                                                                         20    0.000    0.000  /usr/local/lib/python3.11/enum.py:499(__new__)
#                                                                                                                                          4    0.000    0.000  /usr/local/lib/python3.11/enum.py:794(__iter__)
#                                                                                                                                         34    0.000    0.000  /usr/local/lib/python3.11/enum.py:828(__setattr__)
#                                                                                                                                        306    0.000    0.000  /usr/local/lib/python3.11/enum.py:1151(__init__)
#                                                                                                                                          4    0.000    0.000  /usr/local/lib/python3.11/enum.py:1772(<listcomp>)
#                                                                                                                                         62    0.000    0.000  /usr/local/lib/python3.11/http/__init__.py:26(__new__)
#                                                                                                                                          9    0.000    0.000  /usr/local/lib/python3.11/http/__init__.py:163(__new__)
#                                                                                                                                        312    0.000    0.000  /usr/local/lib/python3.11/types.py:164(__init__)
#                                                                                                                                        235    0.000    0.000  {built-in method __new__ of type object at 0x7fde6656be80}
#                                                                                                                                        316    0.000    0.000  {built-in method builtins.getattr}
#                                                                                                                                        615    0.000    0.000  {built-in method builtins.isinstance}
#                                                                                                                                         40    0.000    0.000  {built-in method builtins.issubclass}
#                                                                                                                                        306    0.000    0.000  {built-in method builtins.len}
#                                                                                                                                        332    0.000    0.001  {built-in method builtins.setattr}
#                                                                                                                                          4    0.000    0.000  {built-in method builtins.sorted}
#                                                                                                                                        608    0.000    0.000  {method 'append' of 'list' objects}
#                                                                                                                                          4    0.000    0.000  {method 'bit_length' of 'int' objects}
#                                                                                                                                         40    0.000    0.000  {method 'get' of 'mappingproxy' objects}
#                                                                                                                                         20    0.000    0.000  {method 'items' of 'dict' objects}
#                                                                                                                                         20    0.000    0.000  {method 'items' of 'mappingproxy' objects}
# /usr/local/lib/python3.11/copy.py:66(copy)                                                                                      ->     624    0.000    0.000  /usr/local/lib/python3.11/copy.py:107(_copy_immutable)
#                                                                                                                                       1162    0.002    0.004  /usr/local/lib/python3.11/copy.py:259(_reconstruct)
#                                                                                                                                       2756    0.001    0.001  {built-in method builtins.getattr}
#                                                                                                                                       1162    0.000    0.000  {built-in method builtins.isinstance}
#                                                                                                                                       1594    0.000    0.000  {built-in method builtins.issubclass}
#                                                                                                                                        432    0.000    0.000  {method '__copy__' of 'numpy.ndarray' objects}
#                                                                                                                                       1162    0.001    0.001  {method '__reduce_ex__' of 'object' objects}
#                                                                                                                                       1280    0.000    0.000  {method 'copy' of 'list' objects}
#                                                                                                                                       4660    0.001    0.001  {method 'get' of 'dict' objects}
# /usr/local/lib/python3.11/enum.py:499(__new__)                                                                                  ->     707    0.000    0.000  /usr/local/lib/python3.11/enum.py:239(__init__)
#                                                                                                                                          1    0.000    0.000  /usr/local/lib/python3.11/enum.py:652(<listcomp>)
#                                                                                                                                          1    0.000    0.000  /usr/local/lib/python3.11/enum.py:794(__iter__)
#                                                                                                                                         63    0.000    0.000  /usr/local/lib/python3.11/enum.py:828(__setattr__)
#                                                                                                                                         63    0.000    0.000  /usr/local/lib/python3.11/enum.py:943(_get_mixins_)
#                                                                                                                                         63    0.000    0.000  /usr/local/lib/python3.11/enum.py:965(_find_data_repr_)
#                                                                                                                                         63    0.000    0.001  /usr/local/lib/python3.11/enum.py:1008(_find_new_)
#                                                                                                                                         83    0.003    0.011  {built-in method __new__ of type object at 0x7fde6656be80}
#                                                                                                                                        310    0.000    0.000  {built-in method builtins.delattr}
#                                                                                                                                       1074    0.000    0.000  {built-in method builtins.getattr}
#                                                                                                                                        127    0.000    0.000  {built-in method builtins.issubclass}
#                                                                                                                                         43    0.000    0.000  {built-in method builtins.setattr}
#                                                                                                                                          1    0.000    0.000  {built-in method builtins.sorted}
#                                                                                                                                         63    0.000    0.000  {method 'append' of 'list' objects}
#                                                                                                                                         63    0.000    0.000  {method 'items' of 'dict' objects}
#                                                                                                                                        126    0.000    0.000  {method 'pop' of 'dict' objects}
#                                                                                                                                         63    0.000    0.000  {method 'setdefault' of 'dict' objects}
#                                                                                                                                         63    0.000    0.000  {method 'update' of 'dict' objects}
# /usr/local/lib/python3.11/re/_compiler.py:216(_compile_charset)                                                                 ->    2167    0.000    0.000  {method 'append' of 'list' objects}
#                                                                                                                                        101    0.000    0.000  {method 'extend' of 'list' objects}
# /usr/local/lib/python3.11/re/_parser.py:979(parse)                                                                              ->     367    0.000    0.000  /usr/local/lib/python3.11/re/_parser.py:77(__init__)
#                                                                                                                                        367    0.001    0.001  /usr/local/lib/python3.11/re/_parser.py:231(__init__)
#                                                                                                                                        367    0.001    0.056  /usr/local/lib/python3.11/re/_parser.py:456(_parse_sub)
#                                                                                                                                        367    0.000    0.000  /usr/local/lib/python3.11/re/_parser.py:963(fix_flags)
# /usr/local/lib/python3.11/re/_parser.py:516(_parse)                                                                             ->       6    0.000    0.000  /usr/local/lib/python3.11/re/_parser.py:83(groups)
#                                                                                                                                        426    0.001    0.001  /usr/local/lib/python3.11/re/_parser.py:86(opengroup)
#                                                                                                                                        426    0.000    0.003  /usr/local/lib/python3.11/re/_parser.py:98(closegroup)
#                                                                                                                                          1    0.000    0.000  /usr/local/lib/python3.11/re/_parser.py:100(checkgroup)
#                                                                                                                                          1    0.000    0.000  /usr/local/lib/python3.11/re/_parser.py:103(checklookbehindgroup)
#                                                                                                                                       1123    0.000    0.000  /usr/local/lib/python3.11/re/_parser.py:113(__init__)
#                                                                                                                                       2190    0.001    0.001  /usr/local/lib/python3.11/re/_parser.py:164(__len__)
#                                                                                                                                       8537    0.003    0.005  /usr/local/lib/python3.11/re/_parser.py:168(__getitem__)
#                                                                                                                                       1052    0.000    0.000  /usr/local/lib/python3.11/re/_parser.py:172(__setitem__)
#                                                                                                                                       4335    0.002    0.002  /usr/local/lib/python3.11/re/_parser.py:176(append)
#                                                                                                                                       4853    0.001    0.002  /usr/local/lib/python3.11/re/_parser.py:256(match)
#                                                                                                                                      12641    0.005    0.009  /usr/local/lib/python3.11/re/_parser.py:261(get)
#                                                                                                                                         78    0.000    0.000  /usr/local/lib/python3.11/re/_parser.py:274(getuntil)
#                                                                                                                                       1995    0.001    0.001  /usr/local/lib/python3.11/re/_parser.py:293(tell)
#                                                                                                                                          3    0.000    0.000  /usr/local/lib/python3.11/re/_parser.py:295(seek)
#                                                                                                                                         78    0.000    0.000  /usr/local/lib/python3.11/re/_parser.py:304(checkgroupname)
#                                                                                                                                        236    0.000    0.000  /usr/local/lib/python3.11/re/_parser.py:316(_class_escape)
#                                                                                                                                        633    0.001    0.001  /usr/local/lib/python3.11/re/_parser.py:376(_escape)
#                                                                                                                                        296    0.000    0.001  /usr/local/lib/python3.11/re/_parser.py:453(_uniq)
#                                                                                                                                    526/353    0.002    0.025  /usr/local/lib/python3.11/re/_parser.py:456(_parse_sub)
#                                                                                                                                        151    0.000    0.000  /usr/local/lib/python3.11/re/_parser.py:903(_parse_flags)
#                                                                                                                                       1419    0.001    0.001  {built-in method builtins.len}
#                                                                                                                                       3780    0.000    0.000  {built-in method builtins.ord}
#                                                                                                                                       1205    0.000    0.000  {method 'append' of 'list' objects}
#                                                                                                                                          1    0.000    0.000  {method 'get' of 'dict' objects}
#                                                                                                                                         29    0.000    0.000  {method 'insert' of 'list' objects}
# /usr/local/lib/python3.11/re/_parser.py:1006(parse_template)                                                                    ->       3    0.000    0.000  /usr/local/lib/python3.11/re/_parser.py:231(__init__)
#                                                                                                                                         19    0.000    0.000  /usr/local/lib/python3.11/re/_parser.py:261(get)
#                                                                                                                                          3    0.000    0.000  /usr/local/lib/python3.11/re/_parser.py:1015(addgroup)
#                                                                                                                                          3    0.000    0.000  {built-in method builtins.isinstance}
#                                                                                                                                          3    0.000    0.000  {built-in method builtins.len}
#                                                                                                                                         14    0.000    0.000  {method 'append' of 'list' objects}
#                                                                                                                                          1    0.000    0.000  {method 'join' of 'str' objects}
# /usr/local/lib/python3.11/copy.py:128(deepcopy)                                                                                 ->   31853    0.002    0.002  /usr/local/lib/python3.11/copy.py:182(_deepcopy_atomic)
# ...
#                                                                                                                                     351/95    0.001    1.520  {built-in method builtins.__import__}
#                                                                                                                                         51    0.138    0.138  {built-in method builtins.compile}
#                                                                                                                                     1407/2    0.009    2.464  {built-in method builtins.exec}
# <frozen importlib._bootstrap>:216(_lock_unlock_module)                                                                          ->    1180    0.002    0.003  <frozen importlib._bootstrap>:100(acquire)
#                                                                                                                                       1180    0.001    0.002  <frozen importlib._bootstrap>:125(release)
#                                                                                                                                       1180    0.001    0.001  <frozen importlib._bootstrap>:179(_get_module_lock)
# <frozen importlib._bootstrap>:179(_get_module_lock)                                                                             ->    1564    0.002    0.003  <frozen importlib._bootstrap>:71(__init__)
#                                                                                                                                       2763    0.001    0.001  {built-in method _imp.acquire_lock}
#                                                                                                                                       2763    0.000    0.000  {built-in method _imp.release_lock}
# <frozen importlib._bootstrap>:198(cb)                                                                                           ->    1564    0.000    0.000  {built-in method _imp.acquire_lock}
#                                                                                                                                       1564    0.000    0.000  {built-in method _imp.release_lock}
#                                                                                                                                       1564    0.000    0.000  {method 'get' of 'dict' objects}
# <frozen importlib._bootstrap>:173(__exit__)                                                                                     ->    1583    0.003    0.004  <frozen importlib._bootstrap>:125(release)
# <frozen importlib._bootstrap>:169(__enter__)                                                                                    ->    1583    0.003    0.004  <frozen importlib._bootstrap>:100(acquire)
#                                                                                                                                       1583    0.006    0.009  <frozen importlib._bootstrap>:179(_get_module_lock)
# <frozen importlib._bootstrap>:165(__init__)                                                                                     ->
# <frozen importlib._bootstrap>:125(release)                                                                                      ->    2763    0.000    0.000  {built-in method _thread.get_ident}
#                                                                                                                                       2763    0.001    0.001  {method '__exit__' of '_thread.lock' objects}
# <frozen importlib._bootstrap>:100(acquire)                                                                                      ->    2763    0.001    0.001  {built-in method _thread.get_ident}
#                                                                                                                                       2763    0.001    0.001  {method '__exit__' of '_thread.lock' objects}
# <frozen importlib._bootstrap>:71(__init__)                                                                                      ->    3128    0.001    0.001  {built-in method _thread.allocate_lock}
# <frozen importlib._bootstrap>:48(_new_module)                                                                                   ->
# <frozen ntpath>:1(<module>)                                                                                                     ->       6    0.000    0.013  <frozen importlib._bootstrap>:1165(_find_and_load)
#                                                                                                                                          1    0.000    0.000  {built-in method builtins.hasattr}
# {method '__setstate__' of 'functools.partial' objects}                                                                          ->
# {method 'match' of 're.Pattern' objects}                                                                                        ->
# {method 'fullmatch' of 're.Pattern' objects}                                                                                    ->
# {method 'search' of 're.Pattern' objects}                                                                                       ->
# {method 'sub' of 're.Pattern' objects}                                                                                          ->      47    0.000    0.000  /usr/local/lib/python3.11/inspect.py:1439(repl)
#                                                                                                                                         36    0.000    0.000  /usr/local/lib/python3.11/re/__init__.py:315(_subx)
#                                                                                                                                        116    0.000    0.000  /usr/local/lib/python3.11/re/__init__.py:321(filter)
#                                                                                                                                         48    0.000    0.000  /venv/lib/python3.11/site-packages/scipy/linalg/lapack.py:864(backtickrepl)
# {method 'findall' of 're.Pattern' objects}                                                                                      ->
# {method 'split' of 're.Pattern' objects}                                                                                        ->
# {method 'group' of 're.Match' objects}                                                                                          ->
# {method 'end' of 're.Match' objects}                                                                                            ->
# {method 'groups' of 're.Match' objects}                                                                                         ->
# {method 'groupdict' of 're.Match' objects}                                                                                      ->
# {built-in method from_iterable}                                                                                                 ->
# {method 'append' of 'collections.deque' objects}                                                                                ->
# {method 'extend' of 'collections.deque' objects}                                                                                ->     912    0.001    0.001  /venv/lib/python3.11/site-packages/jinja2/nodes.py:169(iter_child_nodes)
# {method 'pop' of 'collections.deque' objects}                                                                                   ->
# {method 'popleft' of 'collections.deque' objects}                                                                               ->
# {function FreezableDefaultDict.__missing__ at 0x7fde4f0e5c60}                                                                   ->
# {method 'set' of '_contextvars.ContextVar' objects}                                                                             ->
# {method 'reset' of '_contextvars.ContextVar' objects}                                                                           ->
# {method 'index' of 'tuple' objects}                                                                                             ->       1    0.000    0.000  /usr/local/lib/python3.11/typing.py:1388(__eq__)
# {method 'add' of 'set' objects}                                                                                                 ->   30550    0.012    0.161  /workspace/src/geosolver/statement.py:54(__hash__)
#                                                                                                                                      18865    0.015    0.228  /workspace/src/geosolver/statement.py:57(__eq__)
# {method 'copy' of 'set' objects}                                                                                                ->
# {method 'discard' of 'set' objects}                                                                                             ->
# {method 'difference' of 'set' objects}                                                                                          ->
# {method 'intersection' of 'set' objects}                                                                                        ->
# {method 'isdisjoint' of 'set' objects}                                                                                          ->
# {method 'issubset' of 'set' objects}                                                                                            ->
# {method 'issuperset' of 'set' objects}                                                                                          ->
# {method 'pop' of 'set' objects}                                                                                                 ->
# {method 'remove' of 'set' objects}                                                                                              ->
# {method 'union' of 'set' objects}                                                                                               ->
# {method 'update' of 'set' objects}                                                                                              ->
# {method '__contains__' of 'frozenset' objects}                                                                                  ->
# {method 'issuperset' of 'frozenset' objects}                                                                                    ->
# {function RcParams.__getitem__ at 0x7fde4f55eca0}                                                                               ->
# {method 'get' of 'dict' objects}                                                                                                ->       4    0.000    0.000  /usr/local/lib/python3.11/enum.py:1232(__hash__)
#                                                                                                                                         78    0.000    0.000  /venv/lib/python3.11/site-packages/pyparsing/core.py:1982(__hash__)
#                                                                                                                                       1434    0.001    0.009  /workspace/src/geosolver/statement.py:54(__hash__)
# {method 'setdefault' of 'dict' objects}                                                                                         ->
# {method 'pop' of 'dict' objects}                                                                                                ->
# {method 'popitem' of 'dict' objects}                                                                                            ->
# {method 'keys' of 'dict' objects}                                                                                               ->
# {method 'items' of 'dict' objects}                                                                                              ->
# {method 'values' of 'dict' objects}                                                                                             ->
# {method 'update' of 'dict' objects}                                                                                             ->      10    0.000    0.000  /usr/local/lib/python3.11/importlib/metadata/__init__.py:322(_wrap_deprecated_method)
#                                                                                                                                        170    0.000    0.000  /venv/lib/python3.11/site-packages/matplotlib/cm.py:87(__getitem__)
#                                                                                                                                          2    0.000    0.000  <frozen _collections_abc>:786(keys)
#                                                                                                                                        172    0.000    0.000  <frozen _collections_abc>:835(__iter__)
# {built-in method fromkeys}                                                                                                      ->      45    0.000    0.000  /usr/local/lib/python3.11/typing.py:925(__hash__)
#                                                                                                                                        167    0.000    0.000  /usr/local/lib/python3.11/typing.py:1394(__hash__)
#                                                                                                                                          3    0.000    0.000  /usr/local/lib/python3.11/typing.py:1695(__hash__)
#                                                                                                                                         73    0.000    0.000  /usr/local/lib/python3.11/typing.py:1731(__hash__)
# {method 'clear' of 'dict' objects}                                                                                              ->
# {method 'copy' of 'dict' objects}                                                                                               ->
# {method 'clear' of 'list' objects}                                                                                              ->
# {method 'copy' of 'list' objects}                                                                                               ->
# {method 'append' of 'list' objects}                                                                                             ->
# {method 'insert' of 'list' objects}                                                                                             ->
# {method 'extend' of 'list' objects}                                                                                             ->    1272    0.000    0.000  <frozen importlib._bootstrap_external>:1568(<genexpr>)
# {method 'pop' of 'list' objects}                                                                                                ->
# {method 'remove' of 'list' objects}                                                                                             ->
# {method 'index' of 'list' objects}                                                                                              ->
# {method 'count' of 'list' objects}                                                                                              ->
# {method 'reverse' of 'list' objects}                                                                                            ->
# {method 'sort' of 'list' objects}                                                                                               ->     169    0.000    0.000  /usr/local/lib/python3.11/enum.py:918(<lambda>)
# {method 'get' of 'mappingproxy' objects}                                                                                        ->
# {method 'values' of 'mappingproxy' objects}                                                                                     ->
# {method 'items' of 'mappingproxy' objects}                                                                                      ->
# {method 'copy' of 'mappingproxy' objects}                                                                                       ->

# %%
code_to_name = {
    ('/workspace/src/newclid/predicates/equal_ratios.py', 32, 'parse'): 'eqratio',
    ('/workspace/src/newclid/predicates/equal_ratios.py', 36, 'check_numerical'): 'eqratio',
    ('/workspace/src/newclid/predicates/equal_angles.py', 49, 'parse'): 'eqangle',
    ('/workspace/src/newclid/predicates/equal_angles.py', 56, 'check_numerical'): 'eqangle',
    ('/workspace/src/newclid/predicates/cyclic.py', 33, 'parse'): 'cyclic',
    ('/workspace/src/newclid/predicates/cyclic.py', 40, 'check_numerical'): 'cyclic',
    ('/workspace/src/newclid/predicates/parallelism.py', 35, 'parse'): 'para',
    ('/workspace/src/newclid/predicates/parallelism.py', 41, 'check_numerical'): 'para',
    ('/workspace/src/newclid/predicates/triangles_similar.py', 44, 'parse'): 'simtri',
    ('/workspace/src/newclid/predicates/triangles_similar.py', 51, 'check_numerical'): 'simtri',
    ('/workspace/src/newclid/predicates/triangles_similar.py', 100, 'parse'): 'simtrir',
    ('/workspace/src/newclid/predicates/triangles_similar.py', 107, 'check_numerical'): 'simtrir',
    ('/workspace/src/newclid/predicates/circumcenter.py', 34, 'parse'): 'circle',
    ('/workspace/src/newclid/predicates/circumcenter.py', 43, 'check_numerical'): 'circle',
    ('/workspace/src/newclid/predicates/sameclock.py', 30, 'parse'): 'sameclock',
    ('/workspace/src/newclid/predicates/sameclock.py', 39, 'check_numerical'): 'sameclock',
    ('/workspace/src/newclid/predicates/congruence.py', 46, 'parse'): 'cong',
    ('/workspace/src/newclid/predicates/congruence.py', 55, 'check_numerical'): 'cong',
    ('/workspace/src/newclid/statement.py', 17, '__init__'): 'statement instantiation',
}

# %%
def div_bar_diagram(profiles: dict[str, dict[Any, float]], fnames: list[Any]):
    fig, ax = plt.subplots(figsize=(16, 10)) # type:ignore
    colors: Any = plt.cm.tab20.colors # type: ignore
    f_data: dict[Any, dict[str, Any]] = {f:{'color': colors[fnames.index(f) % len(colors)], 'n': 0, 's': 0.} for f in fnames}

    for profile_name, profile_data in profiles.items():
        total = sum(profile_data.values())
        profile_data_sorted = sorted(profile_data.items(), key=lambda t: -t[1])
        cumulative = 0

        for k, v in profile_data_sorted:
            percentage = (v / total) * 100
            color = colors[fnames.index(k) % len(colors)]
            ax.barh(profile_name, percentage, left=cumulative, color=color, align='center', height=0.85)
            f_data[k]['n'] += 1
            f_data[k]['s'] += percentage

            # Improve text visibility with a bold white shadow and slightly larger font size
            if percentage > 10:
                ax.text(cumulative + percentage / 2, profile_name, f"{k}: {percentage:.2f}%", va='center', ha='center',
                        color='black', fontsize=10)
            elif percentage > 5:
                ax.text(cumulative + percentage / 2, profile_name, str(k), va='center', ha='center',
                        color='white', fontsize=10)

            cumulative += percentage

    # Add gridlines, title, and labels for better readability
    ax.grid(True, which='both', axis='x', linestyle='--', linewidth=0.5)
    ax.set_title('Runtime of function calls', fontsize=16, weight='bold')
    ax.set_xlabel('Percentage (%)', fontsize=14)
    ax.set_ylabel('ag_30 problems', fontsize=14)

    for k in list(f_data.keys()):
        if f_data[k]['n'] == 0:
            del f_data[k]
    f_list = [(k, v['color'], v['s']/len(profiles)) for k, v in f_data.items()]
    f_list.sort(key=lambda t: -t[2])

    cumulative = 0
    for t in f_list:
        ax.barh('average', t[2], left=cumulative, color=t[1], align='center', height=0.85)
        if t[2] > 10:
            ax.text(cumulative + t[2] / 2, 'average', f"{t[0]}: {t[2]:.2f}%", va='center', ha='center',
                    color='black', fontsize=10)
        elif t[2] > 5:
            ax.text(cumulative + t[2] / 2, 'average', str(t[0]), va='center', ha='center',
                    color='white', fontsize=10)
        cumulative += t[2]

    handles = [plt.Rectangle((0, 0), 1, 1, color=t[1]) for t in f_list if isinstance(t[0], str)]
    ax.legend(handles, [f"{t[0]}" for t in f_list if isinstance(t[0], str)], bbox_to_anchor=(1, 1), loc='upper left', fontsize=12) # + percentage

    return fig, ax

def draw_profiles(exp: str, entry: Any):
    fnames_set: set[Any] = set()
    profile_exp: dict[str, dict[Any, float]] = {}
    for problem in problems:
        stats = Stats(f'../profiling_{exp}/{problem}/profile.prof')
        stats.calc_callees()
        l = {code_to_name.get(k, k): v[3] for k, v in stats.all_callees[entry].items()} # type: ignore
        profile_exp[problem] = l # type: ignore
        fnames_set.update(l.keys()) # type: ignore
    fnames = list(fnames_set)
    fnames.sort(key=lambda x:(len(x) if isinstance(x, str) else 1000, x))
    div_bar_diagram(profile_exp, fnames)
    plt.margins(0)
    plt.show()

draw_profiles('exp', ('/workspace/src/newclid/statement.py', 60, 'from_tokens'))

# %%
draw_profiles('opt', ('/workspace/src/newclid/statement.py', 60, 'from_tokens'))

# %%
draw_profiles('exp', ('/workspace/src/newclid/statement.py', 38, 'check_numerical'))

# %%
draw_profiles('opt', ('/workspace/src/newclid/statement.py', 38, 'check_numerical'))
